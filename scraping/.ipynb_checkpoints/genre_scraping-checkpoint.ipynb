# %% [markdown]
# ### MAIN_GENRE and Scraping
# We retrieve the genre information from the Rotten Tomatoes website since it is well-known and if frequently updated. Before scraping, we inspected the website using /robots.txt. We then proceeded scraping the information while complying with the instructions posted on the page.
#
# The code used to scrape can be found in web_crawler.py

# %%
# pip install selenium
pip install unidecode
# Out:
#   Cell In[5], line 2
#     pip install unidecode
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.metrics import RocCurveDisplay, recall_score, precision_score, roc_curve, roc_auc_score, balanced_accuracy_score
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# import for scrapping
from unidecode import unidecode
import web_crawler as wc

# %%
comb_df=pd.read_csv('comb_df.csv')

# %%
na_genre = comb_df[comb_df['MAIN_GENRE'].isna()]
na_genre = na_genre.drop_duplicates(subset='show_title')

na_genre_cols = ['category', 'show_title','week']
na_genre = na_genre[na_genre_cols]
print("shape of na_genre initially: ", na_genre.shape)

def mapping_category(string):
  ''' 
  Method to find the category which will later be used in url parsing 
  '''
  string = unidecode(string)

  if(string=="Films (English)"):
    string = "m"
  else:
    string = "tv"
  # print(string)
  return string

def mapping_title(name):
  '''
  Method to find the title name which will later be used in url parsing
  '''
  name = unidecode(name)
  name = name.lower()
  #removing all punctuation
  # https://www.geeksforgeeks.org/python-remove-punctuation-from-string/
  punctuation = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
  for punctuation in punctuation:
    name = name.replace(punctuation, '')
  list = name.split()
  return "_".join(list)

def alt_mapping_category(string):
  """
  Method to find the category which will later be used in url parsing just in case 
  given category was incorrectly listed 
  """

  #in case the type was incorrectly listed 
  string = unidecode(string)
  if(string=="m"):
    string = "tv"
  else:
    string = "m"
  # print(string)
  return string

def mapping_year(week):
  """
  Method to find the release year which will later be used in url parsing in the
  case that shows have duplicate names 
  """
  return week[:4]

na_genre['category'] = na_genre['category'].map(mapping_category)

na_genre['show_title'] = na_genre['show_title'].map(mapping_title)

na_genre['category2'] = na_genre['category'].map(alt_mapping_category)

na_genre['year'] = na_genre['week'].map(mapping_year)

na_genre["url"] = "https://www.rottentomatoes.com/" + na_genre["category"]+"/"+na_genre['show_title']+"_"+na_genre['year'] #first try

na_genre["url2"] = "https://www.rottentomatoes.com/" + na_genre["category"]+"/"+na_genre['show_title'] #second try 

na_genre["url3"] = "https://www.rottentomatoes.com/" + na_genre["category2"]+"/"+na_genre['show_title']+"_"+na_genre['year'] #third try

na_genre["url4"] = "https://www.rottentomatoes.com/" + na_genre["category2"]+"/"+na_genre['show_title'] #fourth try 

na_genre = na_genre.drop_duplicates(subset=['show_title'])

pd.set_option('display.max_columns', None)

na_genre.to_csv("output_filename.csv", index=False, encoding='utf8')

# na_genre.head(50)
# Out:
# shape of na_genre initially:  (1768, 3)

# %%
na_genre.reset_index(drop=True)
# import web_crawler as wc
# Out:
#      category                    show_title        week category2  year  \
# 0           m                    irish_wish  2024-03-24        tv  2024
# 1           m                        damsel  2024-03-24        tv  2024
# 2           m                ford_v_ferrari  2024-03-24        tv  2024
# 3           m         the_casagrandes_movie  2024-03-24        tv  2024
# 4           m                       hellboy  2024-03-24        tv  2024
# ...       ...                           ...         ...       ...   ...
# 1763       tv           murder_by_the_coast  2021-07-04         m  2021
# 1764       tv       rurouni_kenshin_origins  2021-07-04         m  2021
# 1765       tv                    prime_time  2021-07-04         m  2021
# 1766       tv  sophie_a_murder_in_west_cork  2021-07-04         m  2021
# 1767       tv                         katla  2021-07-04         m  2021
#
#                                                     url  \
# 0      https://www.rottentomatoes.com/m/irish_wish_2024
# 1          https://www.rottentomatoes.com/m/damsel_2024
# 2     https://www.rottentomatoes.com/m/ford_v_ferrar...
# 3     https://www.rottentomatoes.com/m/the_casagrand...
# 4         https://www.rottentomatoes.com/m/hellboy_2024
# ...                                                 ...
# 1763  https://www.rottentomatoes.com/tv/murder_by_th...
# 1764  https://www.rottentomatoes.com/tv/rurouni_kens...
# 1765  https://www.rottentomatoes.com/tv/prime_time_2021
# 1766  https://www.rottentomatoes.com/tv/sophie_a_mur...
# 1767       https://www.rottentomatoes.com/tv/katla_2021
#
#                                                    url2  \
# 0           https://www.rottentomatoes.com/m/irish_wish
# 1               https://www.rottentomatoes.com/m/damsel
# 2       https://www.rottentomatoes.com/m/ford_v_ferrari
# 3     https://www.rottentomatoes.com/m/the_casagrand...
# 4              https://www.rottentomatoes.com/m/hellboy
# ...                                                 ...
# 1763  https://www.rottentomatoes.com/tv/murder_by_th...
# 1764  https://www.rottentomatoes.com/tv/rurouni_kens...
# 1765       https://www.rottentomatoes.com/tv/prime_time
# 1766  https://www.rottentomatoes.com/tv/sophie_a_mur...
# 1767            https://www.rottentomatoes.com/tv/katla
#
#                                                    url3  \
# 0     https://www.rottentomatoes.com/tv/irish_wish_2024
# 1         https://www.rottentomatoes.com/tv/damsel_2024
# 2     https://www.rottentomatoes.com/tv/ford_v_ferra...
# 3     https://www.rottentomatoes.com/tv/the_casagran...
# 4        https://www.rottentomatoes.com/tv/hellboy_2024
# ...                                                 ...
# 1763  https://www.rottentomatoes.com/m/murder_by_the...
# 1764  https://www.rottentomatoes.com/m/rurouni_kensh...
# 1765   https://www.rottentomatoes.com/m/prime_time_2021
# 1766  https://www.rottentomatoes.com/m/sophie_a_murd...
# 1767        https://www.rottentomatoes.com/m/katla_2021
#
#                                                    url4
# 0          https://www.rottentomatoes.com/tv/irish_wish
# 1              https://www.rottentomatoes.com/tv/damsel
# 2      https://www.rottentomatoes.com/tv/ford_v_ferrari
# 3     https://www.rottentomatoes.com/tv/the_casagran...
# 4             https://www.rottentomatoes.com/tv/hellboy
# ...                                                 ...
# 1763  https://www.rottentomatoes.com/m/murder_by_the...
# 1764  https://www.rottentomatoes.com/m/rurouni_kensh...
# 1765        https://www.rottentomatoes.com/m/prime_time
# 1766  https://www.rottentomatoes.com/m/sophie_a_murd...
# 1767             https://www.rottentomatoes.com/m/katla
#
# [1768 rows x 9 columns]

# %%
url_df = na_genre[['url','url2','url3','url4']]
url_df.head()
# Out:
#                                                   url  \
# 0    https://www.rottentomatoes.com/m/irish_wish_2024
# 1        https://www.rottentomatoes.com/m/damsel_2024
# 8   https://www.rottentomatoes.com/m/ford_v_ferrar...
# 9   https://www.rottentomatoes.com/m/the_casagrand...
# 10      https://www.rottentomatoes.com/m/hellboy_2024
#
#                                                  url2  \
# 0         https://www.rottentomatoes.com/m/irish_wish
# 1             https://www.rottentomatoes.com/m/damsel
# 8     https://www.rottentomatoes.com/m/ford_v_ferrari
# 9   https://www.rottentomatoes.com/m/the_casagrand...
# 10           https://www.rottentomatoes.com/m/hellboy
#
#                                                  url3  \
# 0   https://www.rottentomatoes.com/tv/irish_wish_2024
# 1       https://www.rottentomatoes.com/tv/damsel_2024
# 8   https://www.rottentomatoes.com/tv/ford_v_ferra...
# 9   https://www.rottentomatoes.com/tv/the_casagran...
# 10     https://www.rottentomatoes.com/tv/hellboy_2024
#
#                                                  url4
# 0        https://www.rottentomatoes.com/tv/irish_wish
# 1            https://www.rottentomatoes.com/tv/damsel
# 8    https://www.rottentomatoes.com/tv/ford_v_ferrari
# 9   https://www.rottentomatoes.com/tv/the_casagran...
# 10          https://www.rottentomatoes.com/tv/hellboy

# %%
scrapped_name, scrapped_cat = wc.automate_data_collection(url_df.to_numpy(), 3)
# Out:
# IS MOVIE
# IRISH WISH
# 2024, Romance/Comedy, 1h 33m
# 39%
# TOMATOMETER
# 59 Reviews
# 44%
# AUDIENCE SCORE
# 250+ Ratings
# IS MOVIE
# DAMSEL
# R 2018, Comedy/Western, 1h 53m
# 67%
# TOMATOMETER
# 119 Reviews
# 53%
# AUDIENCE SCORE
# 500+ Ratings
# IS MOVIE
# FORD V FERRARI
# PG-13 2019, History/Drama, 2h 32m
# 92%
# TOMATOMETER
# 360 Reviews
# 98%
# AUDIENCE SCORE
# 10,000+ Verified Ratings
# ['m', 'm', 'm']

# %%
#Creates a dataframe with genre, show_title, and audience scores for titles with Na values for genre
movie_data = []
i=0
for entry in scrapped_name:
    if entry!= 'NA':
        title, details = entry.split('\n', 1)
        info, tomato_meter, _,_, audience_score, _, _ = details.split('\n')
        comma1=info.find(',')
        comma2=info.rfind(',')
        genre=info[comma1+2:comma2]
        movie_data.append([title, genre, tomato_meter, audience_score])

# Create DataFrame
df = pd.DataFrame(movie_data, columns=['show_title', 'genre', 'tomatometer', 'audience_score'])
# df.to_csv('genreinfo.csv', index=False)

# %%
df
# Out:
#        show_title           genre tomatometer audience_score
# 0      IRISH WISH  Romance/Comedy         39%            44%
# 1          DAMSEL  Comedy/Western         67%            53%
# 2  FORD V FERRARI   History/Drama         92%            98%
